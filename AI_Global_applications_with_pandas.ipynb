# %% [markdown]
# <a href="https://www.kaggle.com/code/iammbrn/ai-global-applications-with-pandas?scriptVersionId=171419503" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ### Pandas ve Numpy kütüphanelerini dahil etmek.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### csv dosyasını okumak.

# %%
data=pd.read_csv("/kaggle/input/ai-index/AI_index_db.csv")

# %% [markdown]
# ### Dataframe verimizdeki columns(öznitelikleri) almak.

# %%
data.columns
# Out:
# Index(['Country', 'Talent', 'Infrastructure', 'Operating Environment',
#        'Research', 'Development', 'Government Strategy', 'Commercial',
#        'Total score', 'Region', 'Cluster', 'Income group', 'Political regime'],
#       dtype='object')

# %% [markdown]
# ### Verimizde bulunan index(veri/satır) sayısını almak.

# %%
len(data.index)
# Out:
# 62

# %% [markdown]
# ### Sütunların veri türleri, eksik değerlerin sayısı ve bellek kullanımı gibi bilgileri almak.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                62 non-null     object
#  1   Talent                 62 non-null     float64
#  2   Infrastructure         62 non-null     float64
#  3   Operating Environment  62 non-null     float64
#  4   Research               62 non-null     float64
#  5   Development            62 non-null     float64
#  6   Government Strategy    62 non-null     float64
#  7   Commercial             62 non-null     float64
#  8   Total score            62 non-null     float64
#  9   Region                 62 non-null     object
#  10  Cluster                62 non-null     object
#  11  Income group           62 non-null     object
#  12  Political regime       62 non-null     object
# dtypes: float64(8), object(5)
# memory usage: 6.4+ KB

# %% [markdown]
# ### Verilerimizin istatiksel özetini almak.

# %%
data.describe().T
# Out:
#                        count       mean        std  min      25%     50%  \
# Talent                  62.0  16.803065  15.214963  0.0   7.3650  13.445
# Infrastructure          62.0  63.503710  20.217525  0.0  55.8575  65.230
# Operating Environment   62.0  66.925484  20.000424  0.0  58.1075  69.505
# Research                62.0  16.610000  17.413996  0.0   3.0325  12.930
# Development             62.0  14.824677  19.419279  0.0   1.2025   9.005
# Government Strategy     62.0  57.865645  26.252448  0.0  41.0300  63.930
# Commercial              62.0   6.171935  14.029632  0.0   0.6975   2.585
# Total score             62.0  23.914677  15.123586  0.0  14.8050  23.220
#
#                            75%    max
# Talent                 24.5675  100.0
# Infrastructure         75.9475  100.0
# Operating Environment  80.5000  100.0
# Research               25.4125  100.0
# Development            19.9800  100.0
# Government Strategy    77.9525  100.0
# Commercial              5.3075  100.0
# ...

# %% [markdown]
# ### Verimizde bulunan ilk beş satırı(index) almak.

# %%
data.head()
# Out:
#                     Country  Talent  Infrastructure  Operating Environment  \
# 0  United States of America  100.00           94.02                  64.56
# 1                     China   16.51          100.00                  91.57
# 2            United Kingdom   39.65           71.43                  74.65
# 3                    Canada   31.28           77.05                  93.94
# 4                    Israel   35.76           67.58                  82.44
#
#    Research  Development  Government Strategy  Commercial  Total score  \
# 0    100.00       100.00                77.39      100.00       100.00
# 1     71.42        79.97                94.87       44.02        62.92
# 2     36.50        25.03                82.82       18.91        40.93
# 3     30.67        25.78               100.00       14.88        40.19
# 4     32.63        27.96                43.91       27.33        39.89
#
#          Region                Cluster  Income group   Political regime
# ...

# %% [markdown]
# ### data dataframe verimizin hepsini görüntülemek.

# %%
data
# Out:
#                      Country  Talent  Infrastructure  Operating Environment  \
# 0   United States of America  100.00           94.02                  64.56
# 1                      China   16.51          100.00                  91.57
# 2             United Kingdom   39.65           71.43                  74.65
# 3                     Canada   31.28           77.05                  93.94
# 4                     Israel   35.76           67.58                  82.44
# ..                       ...     ...             ...                    ...
# 57                 Sri Lanka    6.27           34.64                  35.79
# 58                     Egypt    1.11           38.84                   0.00
# 59                     Kenya    0.75           14.11                  29.84
# 60                   Nigeria    2.74            0.00                  50.10
# 61                  Pakistan    8.00            2.43                  12.48
#
# ...

# %% [markdown]
# ### Country column Türkiye olan data verisini görümtülemek.

# %%
data[data["Country"]=="Turkey"]
# Out:
#    Country  Talent  Infrastructure  Operating Environment  Research  \
# 47  Turkey    8.49           40.74                  64.34      9.53
#
#     Development  Government Strategy  Commercial  Total score  Region  \
# 47         1.02                67.45        0.95        14.39  Europe
#
#       Cluster Income group     Political regime
# 47  Waking up         High  Electoral democracy

# %% [markdown]
# ### Region column içinde bulnan benzersiz verileri görüntülemek.

# %%
data["Region"].unique()
# Out:
# array(['Americas', 'Asia-Pacific', 'Europe', 'Middle East', 'Africa'],
#       dtype=object)

# %% [markdown]
# ### Region column içinde bulnan benzersiz verilerin sayısını almak.

# %%
data["Region"].nunique()
# Out:
# 5

# %% [markdown]
# ### Region column içinde bulnan benzersiz verileri ve sayılarını görüntülemek.

# %%
data["Region"].value_counts()
# Out:
# Region
# Europe          29
# Asia-Pacific    14
# Americas         8
# Middle East      6
# Africa           5
# Name: count, dtype: int64

# %% [markdown]
# ### Region column versine göre Total score verilerinin ortalamasının büyükten küçüğe sıralamasını görüntülemek.

# %%
ratio_Score=data.groupby("Region")[["Total score"]].mean() #Bölgere göre puan ortalaması bulma.
ratio_Score.sort_values("Total score",ascending=False) #Bölgelere göre puan ortalaması sıralması.
# Out:
#               Total score
# Region
# Americas        29.031250
# Asia-Pacific    25.792143
# Europe          25.493103
# Middle East     19.656667
# Africa           6.426000

# %% [markdown]
# ### Region column versi Americas olan Total score data verilerini büyükten küçüğe sıralamasını görüntülemek.

# %%
data[data["Region"]=="Americas"].sort_values("Total score", ascending=False)
# Out:
#                      Country  Talent  Infrastructure  Operating Environment  \
# 0   United States of America  100.00           94.02                  64.56
# 3                     Canada   31.28           77.05                  93.94
# 38                    Brazil   13.46           62.61                  72.82
# 43                    Mexico    1.72           41.85                  97.03
# 44                     Chile   10.56           61.97                  56.73
# 45                 Argentina    8.40           56.15                  75.95
# 48                  Colombia    4.97           54.80                  62.37
# 49                   Uruguay    7.28           58.77                  70.75
#
#     Research  Development  Government Strategy  Commercial  Total score  \
# 0     100.00       100.00                77.39      100.00       100.00
# 3      30.67        25.78               100.00       14.88        40.19
# ...

# %% [markdown]
# ### Region column versi Europe olan Total score data verilerini büyükten küçüğe sıralamasını görüntülemek.

# %%
data[data["Region"]=="Europe"].sort_values("Total score", ascending=False).T
# Out:
#                                           2                  7   \
# Country                       United Kingdom    The Netherlands
# Talent                                 39.65              33.83
# Infrastructure                         71.43              81.99
# Operating Environment                  74.65              88.05
# Research                                36.5              25.54
# Development                            25.03              30.17
# Government Strategy                    82.82              62.35
# Commercial                             18.91               4.97
# Total score                            40.93              36.35
# Region                                Europe             Europe
# Cluster                Traditional champions       Rising stars
# Income group                            High               High
# Political regime           Liberal democracy  Liberal democracy
#
# ...

# %% [markdown]
# ### Political regime verilerine göre Total score verilerinin ortalamasını görüntülemek.

# %%
data.groupby("Political regime")[["Total score"]].mean()
# Out:
#                      Total score
# Political regime
# Closed autocracy       22.375714
# Electoral autocracy    11.815000
# Electoral democracy    18.447500
# Liberal democracy      31.948519

# %% [markdown]
# ### Political regime verilerine göre Total score verilerinin max değerlerini görüntülemek.

# %%
data.groupby("Political regime").max()[["Total score"]].T
# Out:
# Political regime  Closed autocracy  Electoral autocracy  Electoral democracy  \
# Total score                  62.92                30.36                38.67
#
# Political regime  Liberal democracy
# Total score                   100.0

# %% [markdown]
# ### Political regime verilerine göre Total score verilerinin min değerlerini görüntülemek.

# %%
data.groupby("Political regime").min()[["Total score"]]
# Out:
#                      Total score
# Political regime
# Closed autocracy            8.87
# Electoral autocracy         0.00
# Electoral democracy         6.62
# Liberal democracy          13.27

# %% [markdown]
# ### Region verilerine göre Total score, Talent, Research, Infrastructure ve Operating Environment verilerinin ortalamasının Transpozunu görüntülemek.

# %%
data.groupby("Region")[["Total score","Talent","Research","Infrastructure","Operating Environment"]].mean().T
# Out:
# Region                 Africa  Americas  Asia-Pacific     Europe  Middle East
# Total score             6.426  29.03125     25.792143  25.493103    19.656667
# Talent                  4.080  22.20875     17.576429  18.918966     8.166667
# Research                1.342  18.38500     20.723571  17.860690    11.323333
# Infrastructure         28.662  63.40250     64.113571  69.116207    64.123333
# Operating Environment  52.172  74.26875     58.318571  72.409310    63.006667
